# %%
#SoS'26
#analysing dropout trend using data analysis
# Aim- data collection and understanding

# %%
import pandas as pd
import numpy as np
# loading dataset
df_gender= pd.read_csv(' gender.csv')
df_gender
# Out:
#     Sl. No.                                  State/UT  \
# 0         1               Andaman and Nicobar Islands
# 1         2                            Andhra Pradesh
# 2         3                         Arunachal Pradesh
# 3         4                                     Assam
# 4         5                                     Bihar
# 5         6                                Chandigarh
# 6         7                              Chhattisgarh
# 7         8  Dadra and Nagar Haveli and Daman and Diu
# 8         9                                     Delhi
# 9        10                                       Goa
# 10       11                                   Gujarat
# 11       12                                   Haryana
# 12       13                          Himachal Pradesh
# 13       14                         Jammu and Kashmir
# 14       15                                 Jharkhand
# 15       16                                 Karnataka
# ...

# %%
df_gender.head()
# Out:
#    Sl. No.                     State/UT  Primary Drop Out Rate - Boys   \
# 0        1  Andaman and Nicobar Islands                            0.2
# 1        2               Andhra Pradesh                            0.0
# 2        3            Arunachal Pradesh                            9.3
# 3        4                        Assam                            6.8
# 4        5                        Bihar                            0.0
#
#    Primary Drop Out Rate - Girls  Primary Drop Out Rate - Overall  \
# 0                            0.7                              0.4
# 1                            0.0                              0.0
# 2                            9.2                              9.3
# 3                            5.2                              6.0
# 4                            0.0                              0.0
#
#    Upper Primary Drop Out Rate - Boys  Upper Primary Drop Out Rate - Girls  \
# ...

# %%
df_gender.info()
df_gender.describe()
df_gender.isnull().sum()
print(df_gender.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   State/UT                               37 non-null     object
#  1   Primary Drop Out Rate - Boys           37 non-null     float64
#  2   Primary Drop Out Rate - Girls          37 non-null     float64
#  3   Primary Drop Out Rate - Overall        37 non-null     float64
#  4   Upper Primary Drop Out Rate - Boys     37 non-null     float64
#  5   Upper Primary Drop Out Rate - Girls    37 non-null     float64
#  6   Upper Primary Drop Out Rate - Overall  37 non-null     float64
#  7   Secondary Drop Out Rate - Boys         37 non-null     float64
#  8   Secondary Drop Out Rate - Girls        37 non-null     float64
#  9   Secondary Drop Out Rate - Overall      37 non-null     float64
# dtypes: float64(9), object(1)
# memory usage: 3.0+ KB
# ...

# %%
# uploading dataset for level
df_level =pd.read_csv( "level.csv")
df_level.head()
df_level.info()
df_level.describe()
df_level.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Sl. No.                              38 non-null     object
#  1   State/UT                             38 non-null     object
#  2   Primary level (I - V) - Boys         36 non-null     float64
#  3   Primary level (I - V) - Girls        36 non-null     float64
#  4   Primary level (I - V) - Total        36 non-null     float64
#  5   Upper Primary - Boys                 36 non-null     float64
#  6   Upper Primary - Girls                36 non-null     float64
#  7   Upper Primary - Total                36 non-null     float64
#  8   Elementary level (I - VIII) - Boys   36 non-null     float64
#  9   Elementary level (I - VIII) - Girls  36 non-null     float64
#  10  Elementary level (I - VIII) - Total  36 non-null     float64
# ...

# %%
# dataset for trend 2017 vs 2019
df_trend = pd.read_csv(" trend.csv")
df_trend.head()
df_trend.info()
df_trend.describe()
df_trend.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State/UT                 38 non-null     object
#  1   2017-18 - Primary        37 non-null     float64
#  2   2017-18 - Upper Primary  37 non-null     float64
#  3   2017-18 - Secondary      37 non-null     float64
#  4   2018-19 - Primary        37 non-null     float64
#  5   2018-19 - Upper Primary  37 non-null     float64
#  6   2018-19 - Secondary      37 non-null     float64
#  7   2019-20 - Primary        38 non-null     float64
#  8   2019-20 - Upper Primary  38 non-null     float64
#  9   2019-20 - Secondary      38 non-null     float64
# dtypes: float64(9), object(1)
# memory usage: 3.1+ KB
# State/UT                   0
# 2017-18 - Primary          1
# 2017-18 - Upper Primary    1
# 2017-18 - Secondary        1
# 2018-19 - Primary          1
# ...
